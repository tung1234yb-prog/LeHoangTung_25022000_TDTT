# %%
#Bai 1
a,b= map(int, input().split())
print(a*b, a+b)
# Out:
# 20 9

# %%
#Bai 2
r= int(input())
print(r**2*3.14, 2*r*3.14)
# Out:
# 28.26 18.84

# %%
#Bai 3
a,b,c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
    if a==b and b==c and c==a:
        print('Tam giac deu')
    elif a==b or b==c or a==c:
        print('Tam giac can')
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print('Tam giac vuong')
    else:
        print('Tam giac thuong')
    p= (a+b+c)/2
    print( a+b+c, (p*(p-a)*(p-b)*(p-c))**(1/2))
# Out:
# Tam giac thuong
# 15 9.921567416492215

# %%
#Bai 4
a,b= map(int, input().split())
if a!=0:
    print('Phuong trinh co nghiem x=', -b/a)
elif a == 0 and b == 0: 
    print('Phuong trinh co vo so nghiem')
else:
    print('Phuong trinh vo nghiem')
# Out:
# Phuong trinh co nghiem x= -1.25

# %%
#Bai 5
a,b,c= map(int, input().split())
d= b**2-4*a*c
if d<0:
    print('Phuong trinh vo nghiem')
elif d==0:
    print('Phuong trinh co nghiem kep x=', -b/(2*a))
else:
    print(f'Phuong trinh co 2 nghiem x1= {-(d**(1/2)+b)/(2*a)} va x2= {-(d**(1/2)-b)/(2*a)}')
# Out:
# Phuong trinh co 2 nghiem x1= -1.0 va x2= 0.3333333333333333

# %%
#Bai 6
a,b,c,d = map(int, input().split())
if a>b and a>c and a>d:
    print(a)
elif b>a and b>c and b>d:
    print(b)
elif c>a and c>b and c>d:
    print(c)
elif d>a and d>b and d>c:
    print(d)
# Out:
# 9

# %%
#Bai 7
a,b,c,d = map(int, input().split())
if a<b and a<c and a<d:
    print(a)
elif b<a and b<c and b<d:
    print(b)
elif c<a and c<b and c<d:
    print(c)
elif d<a and d<b and d<c:
    print(d)
# Out:
# 1

# %%
#Bai 8
a,b,m = map(int, input().split())
c,d,n = map(int, input().split())
d1= b-d*a/c
n1= m-n*a/c
if n1==0 and d1==0:
    print('He phuong trinh co vo so nghiem')
elif n1!=0 and d1==0:
    print('He phuong trinh vo nghiem')
else:
    print(f'He phuong trinh co nghiem x= {m/a} va y= {0}')
# Out:
# He phuong trinh co nghiem x= 1.5 va y= 0

# %%
#Bai 9
n= int(input())
print(f'{n//3600} gio, {n%3600//60} phut, {n%3600%60} giay')
# Out:
# 1 gio, 0 phut, 2 giay

# %%
#Bai 10
a, b, r= map(int, input().split())
x, y= map(int, input().split())
if (x-a)**2 + (y-b)**2 == r**2:
    print(f'Diem A({x},{y}) thuoc duong tron')
else:
    print(f'Diem A({x},{y}) khong thuoc duong tron')
# Out:
# Diem A(2,4) khong thuoc duong tron

# %%
#Bai 11
x,y= map(float, input().split())
print(x**y)
# Out:
# 4096.0
