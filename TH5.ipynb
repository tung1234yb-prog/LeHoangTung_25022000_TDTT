# %%
#W5A1
def Max_Of_Two(a, b):
    if a > b:
        return a
    else:
        return b

# %%
#W5A2
def swap(a, b):
    temp = a
    a = b
    b = temp
    return a, b

# %%
#W5A3
def check(n):
    if n == 1:
        print(n, 'khong phai la so nguyen to')
    flag = True
    for i in range (2, n**(1/2)+1):
        if n % i == 0:
            flag = False
            break
    if flag:
        print(n, 'la so nguyen to')
    else: 
        print(n, 'khong phai la so nguyen to')

# %%
#W5A4
def check(n):
    tong = 0
    for i in range (1, n):
        if n % i == 0:
            tong += i
    return tong == n

# %%
#W5A5
def abc():
    lst = list(map(int, input().split()))
    while True:
        k = int(input())
        if k > 0:
            break
    for i in range (0, len(lst)):
        if lst[i] == k:
            return i
        else:
            return -1
# Out:
# 0

# %%
#W5A6
def gt(n):
    tich = 1
    for i in range (1, n+1):
        tich *= i
    return tich

# %%
#W5A7
def cal(n1, n2, op):
    match op:
        case '+':
            res = n1 + n2
        case '-':
            res = n1 - n2
        case '*':
            res = n1 * n2
        case '/':
            res = n1 / n2
    return f'{res:.2f}'

# %%
#W5A9
def sum(n):
    while n > 0:
        res = 0
        res += n % 10 
        n //= 10
    return res

# %%
#W5A10
def check(a, b):
    for i in range(0, len(a)):
        for j in range(i+1, len(a)):
            if a[i] == a[j] and (ord(a[i]) - ord(b[i])) != (ord(a[j]) - ord(b[j])):
                return False
    return True
# Out:
# False
